# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaFZ/-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes

# %%
import json

# 模拟 3 条示波器指令数据
dummy_data = [
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "关闭通道1的显示", "output": ":SELect:CH1 OFF"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "把第一通道关掉", "output": ":SELect:CH1 OFF"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "隐藏 CH1 波形", "output": ":SELect:CH1 OFF"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "打开通道2", "output": ":SELect:CH2 ON"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "显示第二通道", "output": ":SELect:CH2 ON"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "CH2 Set ON", "output": ":SELect:CH2 ON"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "查询通道1目前的显示状态", "output": ":SELect:CH1?"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "第一通道是开着还是关着？", "output": ":SELect:CH1?"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "禁用通道1", "output": ":SELect:CH1 0"},
{"instruction": "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", "input": "启用通道2显示", "output": ":SELect:CH2 1"},
]

# 将数据写入当前目录下的 train.jsonl
with open("train.jsonl", "w", encoding="utf-8") as f:
    for entry in dummy_data:
        json.dump(entry, f, ensure_ascii=False)
        f.write("\n")

print("✅ 测试文件 train.jsonl 已生成！请重新运行刚才报错的那段代码。")
# Out:
# ✅ 测试文件 train.jsonl 已生成！请重新运行刚才报错的那段代码。

# %%
from unsloth import FastLanguageModel

# 直接从 Drive 路径加载你训练好的补丁
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "/content/drive/MyDrive/oscilloscope_project/lora_model",
    # 其他参数保持不变...
)

# %%
import torch
from unsloth import FastLanguageModel

# 2. 配置模型参数
max_seq_length = 2048 # 序列长度，示波器指令通常很短，2048 足够了
dtype = None # 自动检测数据类型（Float16 或 Bfloat16）
load_in_4bit = True # 开启 4bit 量化，省显存的关键

# 3. 加载模型
# 如果你以后要换其他模型，改这个 model_name 即可
model_name = "Qwen/Qwen3-0.6B"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

# 4. 转换模型为 LoRA 模式（微调模式）
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # LoRA 的秩，建议 8, 16, 32
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # 为了优化速度设为 0
    bias = "none",    # 为了优化速度设为 none
    use_gradient_checkpointing = "unsloth", # 开启显存优化
    random_state = 3407,
)
# Out:
# ==((====))==  Unsloth 2026.1.4: Fast Qwen3 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2026.1.4 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
from datasets import load_dataset

# 5. 定义数据处理格式
# 将你的 JSONL 格式转换为模型能听懂的 Prompt 格式
alpaca_prompt = """Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # 句子结束符

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # 填充模板
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# 6. 加载并处理数据集
# 确保你的文件名是 'train.jsonl'
dataset = load_dataset("json", data_files="train.jsonl", split="train")
dataset = dataset.map(formatting_prompts_func, batched = True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

# 7. 设置训练参数
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # 如果数据量很大可以设为 True 加速
    args = TrainingArguments(
        per_device_train_batch_size = 8, # 0.5B 模型很小，这里可以开大一点，比如 8 或 16
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60, # 训练步数。如果你数据多，可以设为 0 并使用 num_train_epochs = 1
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)

# 8. 开始训练
trainer_stats = trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 10 | Num Epochs = 60 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 4 x 1) = 32
#  "-____-"     Trainable parameters = 10,092,544 of 606,142,464 (1.67% trained)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# ...

# %%
# 建议在 Drive 里建一个专门的文件夹，比如 'oscilloscope_project'
import os
save_path = "/content/drive/MyDrive/oscilloscope_project/lora_model"

if not os.path.exists(save_path):
    os.makedirs(save_path)

model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
print(f"✅ 模型已安全保存到 Google Drive: {save_path}")
# Out:
# ✅ 模型已安全保存到 Google Drive: /content/drive/MyDrive/oscilloscope_project/lora_model

# %%
# 简单测试
FastLanguageModel.for_inference(model) # 开启推理模式
inputs = tokenizer(
[
    alpaca_prompt.format(
        "你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。", # instruction
        "关闭 CH1", # input
        "", # output - 留空让模型生成
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
print(tokenizer.batch_decode(outputs))

# 保存模型 (保存 LoRA 适配器，这是最轻量的方式)
model.save_pretrained("lora_model") # 保存到左侧文件夹
# tokenizer.save_pretrained("lora_model")
# Out:
# ['Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n你是一个示波器助手。将用户的自然语言转换为标准的 ADS 系列 SCPI 指令。\n\n### Input:\n关闭 CH1\n\n### Response:\n:SELect:CH1 OFF<|im_end|>']

# %%
# !pip install "sympy==1.14.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 76.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# ...

# %%
import sympy
print(f"当前 SymPy 版本: {sympy.__version__}")
# Out:
# 当前 SymPy 版本: 1.14.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
